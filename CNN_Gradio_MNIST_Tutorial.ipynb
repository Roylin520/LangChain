# %% [markdown]
# # CNN Gradio MNIST Tutorial

# %%
# !pip install gradio==3.50
# Out:
# Collecting gradio==3.50
#   Downloading gradio-3.50.0-py3-none-any.whl.metadata (17 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio==3.50)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.13/dist-packages (from gradio==3.50) (5.5.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.13/dist-packages (from gradio==3.50) (0.141.1)
# Collecting ffmpy (from gradio==3.50)
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==0.6.1 (from gradio==3.50)
#   Downloading gradio_client-0.6.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.13/dist-packages (from gradio==3.50) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.13/dist-packages (from gradio==3.50) (1.28.0)
# Collecting importlib-resources<7.0,>=1.3 (from gradio==3.50)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.13/dist-packages (from gradio==3.50) (3.1.6)
# Collecting markupsafe~=2.0 (from gradio==3.50)
#   Downloading MarkupSafe-2.1.5.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.13/dist-packages (from gradio==3.50) (3.10.0)
# Collecting numpy~=1.0 (from gradio==3.50)
#   Downloading numpy-1.26.4.tar.gz (15.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 91.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done

# %%
import tensorflow as tf
import gradio as gr
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train[100]

# %%
y_train[100]

# %%
256*256*256*0.92

# %%
x_train = x_train / 255.0,
x_test = x_test / 255.0

# %%
28*28

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128,activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=6)

# %%
import numpy as np

def classify(image):
  image = np.expand_dims(image, axis=0)
  prediction = model.predict(image).tolist()[0]
  return {str(i):prediction[i] for i in range(10)}

label = gr.outputs.Label(num_top_classes=3)
interface = gr.Interface(classify, 'sketchpad', label, capture_session=True,interpretation="default",title = 'Digit Classifier')
interface.launch(debug=True)

# %%
# !pip show torch

# %%
# !pip show scikit-learn

# %%
# !pip install -U scikit-learn

# %%
# !pip show scikit-learn
